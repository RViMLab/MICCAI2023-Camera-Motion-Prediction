# %%
import sys
sys.path.append("/home/martin/Dev/homography_imitation_learning")
import os
import pandas as pd

from utils.io import recursive_scan2df
from utils.processing import MultiProcessVideoSequencer

from endoscopy import max_rectangle_in_circle

prefix = "/media/martin/Samsung_T5/data/endoscopic_data/cholec80_circle_tracking_individual/df_interpolated"
data_df = recursive_scan2df(prefix, ".pkl")

# load frame -> crop frame to shape -> crop frame batch-wise at center, radius via max_rectangle_in_circle
# 
# 

for _, row in data_df.iterrows():
    df = pd.read_pickle(os.path.join(prefix, row.folder, row.file))
    

    # resize
    max_rectangle_in_circle()

    # find by index (vid + frame)
    # accumulate
    # crop

    # load images and corresponding centers etc according to video frame index
    # accumulate centers, radii, shapes with images
    # crop and resize given boxes
# Out:
#        Unnamed: 0  vid  frame                                    center  \
# 0               0    0      0   [254.54449462890625, 313.7264404296875]
# 1               1    0      1   [256.73858642578125, 313.2445373535156]
# 2               2    0      2    [255.1600341796875, 316.0122985839844]
# 3               3    0      3   [251.40309143066406, 315.4839172363281]
# 4               4    0      4   [251.1868133544922, 312.07147216796875]
# ...           ...  ...    ...                                       ...
# 43295       43295    0  43295  [246.13204956054688, 310.18841552734375]
# 43296       43296    0  43296  [246.13204956054688, 310.18841552734375]
# 43297       43297    0  43297  [246.13204956054688, 310.18841552734375]
# 43298       43298    0  43298  [246.13204956054688, 310.18841552734375]
# 43299       43299    0  43299  [246.13204956054688, 310.18841552734375]
#
#            radius          shape  radius_running_average_25  \
# ...
